# %%
#import pandas as pd
import pandas as pd
#read file using pd
file=pd.read_csv("sentiment_analysis_pos_neg.csv")
#get length of file
length=file.index.size
Total = 0
index = 0
oriTrade = 1000

#initialize for loop create variables and link then to elements in file
for i in range (length):
    variableList = [(file.at[i,"Positives"]), (file.at[i,"Negatives"]), (file.at[i,"Neutrals"]), (file.at[i,"Undefineds"]), (file.at[i, "Rating"]), (file.at[i, "Price"])]
   
    #create if statements for condition 1 "if positives are greater than the largest of negatives, undefined, and neutrals
    if variableList[0] > variableList[1] and variableList[0] > variableList[2] and variableList[0] > variableList[3]:
        #multiply rating by positives/negatives 
        Factor = variableList[4] * (variableList[0]/variableList[1])
        TradeAmount = oriTrade * Factor
        Total=Total+TradeAmount
        Condition = 1   
    # create if statements for condition 2 if statement "if negatives are greater than the largest of positive, undefined and neutral"
    elif variableList[1] > variableList[0] and variableList[1] > variableList[2] and variableList[1] > variableList[3]:
        Factor = variableList[4] * ((variableList[0]+variableList[3])/(variableList[1]+variableList[3]))
        TradeAmount = oriTrade*Factor
        Total=Total+TradeAmount
        Condition = 2   
        
    # create if statements for condition 3 if statement "if neutrals are greater than positive, negative and undefined"
    elif variableList[2] > variableList[0] or variableList[2] > variableList[3]:
        #if   undefined and positives>negatives,multiply rating by positives/(negatives+undefined)
        if variableList[0] > variableList[1]:
            Factor = variableList[4] * ((variableList[0])/(variableList[1]+variableList[3]))
            TradeAmount = oriTrade*Factor
            Total=Total+TradeAmount
            Condition = 3                          
        #if undefined and negatives>positives, multiply rating by (positives+undef)/(negatives+undef)
        elif variableList[1] > variableList[0]:
            Factor = variableList[4] * ((variableList[0]+variableList[3])/(variableList[1]+variableList[3]))
            TradeAmount = oriTrade*Factor
            Total=Total+TradeAmount
            Condition = 3
                               

#print("At index: ", i)    print("Price: ", Price)   
#print("Condition ", Condition, ": ", TradeAmount)  
#print("Buy or sell or ignore")
#print("Factor: ", Factor)     print("Total: ", Total)    #print("=================")
    print("At index: ", i)
    print("Price: ", variableList[5])
    if Price <= variableList[4]*oriTrade:
        print("Buy!")
    elif variableList[5] >= variableList[4]*oriTrade:
        print("Short!")
    print("Condition ", Condition, ": Trade amount is: ", TradeAmount)
    print("Factor: ", Factor) 
    print("Total: ", Total)
    print("=================")
# Out:
# At index:  0
# Price:  7773.8456
# Buy!
# Condition  2 : Trade amount is:  6551.28897432071
# Factor:  6.55128897432071
# Total:  6551.28897432071
# =================
# At index:  1
# Price:  3806.4205
# Short!
# Condition  3 : Trade amount is:  2567.7079294692685
# Factor:  2.5677079294692686
# Total:  9118.99690378998
# =================
# At index:  2
# Price:  3889.5840000000003
# Short!
# Condition  1 : Trade amount is:  22082.071386350268
# Factor:  22.08207138635027
# Total:  31201.068290140247
# =================
# At index:  3
# Price:  1075.4723
# Buy!
# Condition  1 : Trade amount is:  42396.64425927211
# Factor:  42.39664425927211
# Total:  73597.71254941236
# =================
# At index:  4
# Price:  7781.3044
# Buy!
# Condition  1 : Trade amount is:  42396.64425927211
# Factor:  42.39664425927211
# Total:  73597.71254941236
# =================
# At index:  5
# Price:  6301.767
# Buy!
# Condition  3 : Trade amount is:  5883.26220281292
# Factor:  5.88326220281292
# Total:  79480.97475222529
# =================
# At index:  6
# Price:  9044.0135
# Buy!
# Condition  2 : Trade amount is:  9177.03504547453
# Factor:  9.177035045474529
# Total:  88658.00979769982
# =================
# At index:  7
# Price:  5991.8964
# Buy!
# Condition  2 : Trade amount is:  5048.862909054779
# Factor:  5.04886290905478
# Total:  93706.8727067546
# =================
# At index:  8
# Price:  13707.3885
# Buy!
# Condition  1 : Trade amount is:  26947.73913575605
# Factor:  26.94773913575605
# Total:  120654.61184251064
# =================
# At index:  9
# Price:  15038.8806
# Buy!
# Condition  2 : Trade amount is:  4973.650595596437
# Factor:  4.973650595596436
# Total:  125628.26243810708
# =================
# At index:  10
# Price:  9156.1632
# Buy!
# Condition  1 : Trade amount is:  12989.714296070048
# Factor:  12.989714296070048
# Total:  138617.97673417712
# =================
# At index:  11
# Price:  883.938108
# Short!
# Condition  1 : Trade amount is:  12989.714296070048
# Factor:  12.989714296070048
# Total:  138617.97673417712
# =================
# At index:  12
# Price:  5726.2795
# Buy!
# Condition  3 : Trade amount is:  5228.087369020078
# Factor:  5.228087369020078
# Total:  143846.0641031972
# =================
# At index:  13
# Price:  12356.9445
# Buy!
# Condition  3 : Trade amount is:  3874.9553923788267
# Factor:  3.8749553923788267
# Total:  147721.019495576
# =================
# At index:  14
# Price:  14984.94
# Buy!
# Condition  2 : Trade amount is:  3880.613766634722
# Factor:  3.8806137666347222
# Total:  151601.63326221073
# =================
# At index:  15
# Price:  6409.34
# Short!
# Condition  1 : Trade amount is:  12663.318798098631
# Factor:  12.663318798098631
# Total:  164264.95206030936
# =================
# At index:  16
# Price:  4896.1809
# Buy!
# Condition  1 : Trade amount is:  4820.413437432177
# Factor:  4.820413437432177
# Total:  169085.36549774153
# =================
# At index:  17
# Price:  7128.5592
# Buy!
# Condition  2 : Trade amount is:  4132.841254623764
# Factor:  4.132841254623764
# Total:  173218.20675236528
# =================
# At index:  18
# Price:  19129.4595
# Buy!
# Condition  3 : Trade amount is:  4035.838786696112
# Factor:  4.035838786696112
# Total:  177254.0455390614
# =================
# At index:  19
# Price:  1122.06293
# Short!
# Condition  3 : Trade amount is:  4035.838786696112
# Factor:  4.035838786696112
# Total:  177254.0455390614
# =================
# At index:  20
# Price:  1627.857295
# Short!
# Condition  1 : Trade amount is:  2286.646667931993
# Factor:  2.286646667931993
# Total:  179540.69220699338
# =================
# At index:  21
# Price:  3291.0733
# Short!
# Condition  1 : Trade amount is:  6564.1266123348305
# Factor:  6.564126612334831
# Total:  186104.8188193282
# =================
# At index:  22
# Price:  4403.1556
# Buy!
# Condition  1 : Trade amount is:  6564.1266123348305
# Factor:  6.564126612334831
# Total:  186104.8188193282
# =================
# At index:  23
# Price:  3270.0674
# Short!
# Condition  2 : Trade amount is:  3109.5894899057485
# Factor:  3.1095894899057486
# Total:  189214.40830923396
# =================
# At index:  24
# Price:  15382.549519999999
# Buy!
# Condition  3 : Trade amount is:  4340.14532565413
# Factor:  4.34014532565413
# Total:  193554.55363488809
# =================
# At index:  25
# Price:  18050.2029
# Buy!
# Condition  2 : Trade amount is:  7159.6770353544525
# Factor:  7.159677035354452
# Total:  200714.23067024254
# =================
# At index:  26
# Price:  3323.2423
# Short!
# Condition  2 : Trade amount is:  2750.423073218192
# Factor:  2.750423073218192
# Total:  203464.65374346075
# =================
# At index:  27
# Price:  4738.8818
# Buy!
# Condition  3 : Trade amount is:  1644.517796652974
# Factor:  1.644517796652974
# Total:  205109.17154011372
# =================
# At index:  28
# Price:  2633.3589
# Condition  2 : Trade amount is:  733.9215206783508
# Factor:  0.7339215206783508
# Total:  205843.09306079207
# =================
# At index:  29
# Price:  15466.7806
# Buy!
# Condition  3 : Trade amount is:  6823.982597350017
# Factor:  6.823982597350017
# Total:  212667.0756581421
# =================
# At index:  30
# Price:  9078.103000000001
# Buy!
# Condition  1 : Trade amount is:  48237.29662804919
# Factor:  48.23729662804919
# Total:  260904.3722861913
# =================
# At index:  31
# Price:  6989.0378
# Buy!
# Condition  1 : Trade amount is:  8869.69947710558
# Factor:  8.869699477105579
# Total:  269774.0717632969
# =================
# At index:  32
# Price:  8364.2079
# Buy!
# Condition  3 : Trade amount is:  8169.892143506605
# Factor:  8.169892143506605
# Total:  277943.9639068035
# =================
# At index:  33
# Price:  254.43677999999997
# Condition  1 : Trade amount is:  973.2756717388204
# Factor:  0.9732756717388203
# Total:  278917.23957854236
# =================
# At index:  34
# Price:  4074.1325
# Short!
# Condition  1 : Trade amount is:  973.2756717388204
# Factor:  0.9732756717388203
# Total:  278917.23957854236
# =================
# At index:  35
# Price:  1460.4510599999999
# Short!
# Condition  1 : Trade amount is:  4902.5665050993
# Factor:  4.9025665050993
# Total:  283819.80608364166
# =================
# At index:  36
# Price:  5845.8861
# Buy!
# Condition  2 : Trade amount is:  6085.858523775916
# Factor:  6.085858523775916
# Total:  289905.6646074176
# =================
# At index:  37
# Price:  2283.5768
# Condition  2 : Trade amount is:  1534.2971916530198
# Factor:  1.5342971916530197
# Total:  291439.9617990706
# =================
# At index:  38
# Price:  3289.0878
# Short!
# Condition  2 : Trade amount is:  1534.2971916530198
# Factor:  1.5342971916530197
# Total:  291439.9617990706
# =================

# %%
#trading algo with user input

stock = [input("name of stock"), input("stock ticker"), input("price")]
print(stock)

sentiment = input("What is the sentiment (negative or positve)?")
stock.append(sentiment)

print(stock)
# Out:
# name of stock1234
# stock ticker1234
# price1234
# ['1234', '1234', '1234']
# What is the sentiment (negative or positve)?1234
# ['1234', '1234', '1234', '1234']

# %%
stock = [input("name of stock"), input("stock ticker"), input("price"), 0 , 0 , 0]
print(stock)

breaker = 'Y'
while(breaker == 'Y'):
    
    stock[3] = int(input("What is the sentiment (negative or positve)?"))
    print(stock)

    stock[4] = int(input("What is the number of neutrals"))
    stock[5] = int(input("What is the number of undefineds"))
    print(stock)

    if stock[3] > stock[4] and stock[5]:
        print("Buy")
    elif abs(stock[3]) > stock[4] and stock[5]:
        print("Sell")
    else:
        print("Do Nothing")
        
    breaker = input("New sentiments? Answer 'Y' or 'N'")


print("End of Program")
# Out:
# name of stockAAPLe
# stock tickerAAPLE
# price135
# ['AAPLe', 'AAPLE', '135', 0, 0, 0]
# What is the sentiment (negative or positve)?100
# ['AAPLe', 'AAPLE', '135', 100, 0, 0]
# What is the number of neutrals20
# What is the number of undefineds30
# ['AAPLe', 'AAPLE', '135', 100, 20, 30]
# Buy
# New sentiments? Answer 'Y' or 'N'N
# End of Program
