# %%
#Missed from last class

n=0
while n<=0:
    n=int(input("enter a positive number: "))
while n!=1:
    print (n)
    #check if n is even

    if n%2==0:
        n=n/2
    else:
        n=n*3+1
# Out:
# enter a positive number: 12
# 12
# 6.0
# 3.0
# 10.0
# 5.0
# 16.0
# 8.0
# 4.0
# 2.0

# %%
#MISSED LAST CLASS NOTES

#RATING=FACTOR
#if positives are >  undefined, neutral, negative
    #factor = factor*(positive / greatest of undefined, neutral, negative)
#if negatives are > positives, undefined, neutral
    #factor is reduced
    #factor = factor * (positives/negatives)
#otherwise stick to the same factor in the csv
#each trade = newfactor * 10000
#stop at 1000000
import pandas as pd
file=pd.read_csv("sentiment_analysis_pos_neg.csv")
length=file.index.size
Total = 0
for i in range (length):
    Positives = (file.at[i,"Positives"])
    Negatives = (file.at[i,"Negatives"])
    Neutrals = (file.at[i,"Neutrals"])
    Undefineds = (file.at[i,"Undefineds"])
    Rating = (file.at[i, "Rating"])
    
    
    if Positives > Undefineds and Positives > Negatives and Positives > Neutrals:
        q=max(Undefineds, Neutrals, Negatives)
        Factor = Rating*(Positives/q)
        TradeAmount=10000*Factor
        Total=Total+TradeAmount
        print("1Trade amount: ", TradeAmount, "Factor: ", Factor, "Total: ", Total)
        
        
    elif Negatives > Undefineds and Negatives > Positives and Negatives > Neutrals:
        Factor = Rating*(Positives/Negatives)
        TradeAmount=10000*Factor
        Total=Total+TradeAmount
        print("2Trade amount: ", TradeAmount, "Factor: ", Factor, "Total: ", Total)
        
        
    else:
        Factor = Rating
        TradeAmount=10000*Factor
        Total=Total+TradeAmount
        print("3Trade amount: ", TradeAmount, "Factor: ", Factor, "Total: ", Total)

#ALMOST GOT IT WORKING
# Out:
# 2Trade amount:  63363.12521844926 Factor:  6.336312521844926 Total:  63363.12521844926
# 3Trade amount:  31144.13892 Factor:  3.114413892 Total:  94507.26413844926
# 1Trade amount:  30976.843741850113 Factor:  3.097684374185011 Total:  125484.10788029937
# 1Trade amount:  166939.7942890947 Factor:  16.69397942890947 Total:  292423.9021693941
# 3Trade amount:  48698.38557 Factor:  4.869838557 Total:  341122.28773939406
# 3Trade amount:  61867.12241 Factor:  6.186712241 Total:  402989.41014939407
# 2Trade amount:  88104.39958476194 Factor:  8.810439958476193 Total:  491093.809734156
# 2Trade amount:  49410.23401960181 Factor:  4.941023401960181 Total:  540504.0437537578
# 1Trade amount:  159983.1629744829 Factor:  15.99831629744829 Total:  700487.2067282407
# 2Trade amount:  22645.160765761946 Factor:  2.2645160765761947 Total:  723132.3674940027
# 1Trade amount:  129897.14296070048 Factor:  12.989714296070048 Total:  853029.5104547031
# ...

# %%
check = input("input a number")
if int(check)==True: #Checks if it is a positive Integer
    print("True")
else:
    print("false")
# Out:
# input a number100
# false

# %%
check = input("input a number")
if int(check): #Checks if it is a number
    print("True")
else:
    print("false")
# Out:
# input a number-21
# True

# %%
check = input("input a number")
if (check): #checks if there is any input. 
    print("True")
else:
    print("false")
# Out:
# input a number
# false

# %%
## GPA calculator
#Ask the user for the gradein class AC11, AC12, IS100, OM101, FI101 
sumOfGrades = 0
numOfClasses = 0

AC11Grade = input("What was your Grade in AC11: ")
print ("AC11",int(AC11Grade))
if int(AC11Grade): #Checks if it is a positive Integer
    sumOfGrades = sumOfGrades + int(AC11Grade)
    numOfClasses = numOfClasses + 1
else:
    print("AC11 is not true", AC11Grade)
AC12Grade = input("What was your Grade in AC12: ")
if int(AC12Grade)==True: #Checks if it is a positive Integer
    sumOfGrades = sumOfGrades + int(AC12Grade)
    numOfClasses = numOfClasses + 1
IS100Grade = input("What was your Grade in IS100: ")
if int(IS100Grade)==True: #Checks if it is a positive Integer
    sumOfGrades = sumOfGrades + int(IS100Grade)
    numOfClasses = numOfClasses + 1
OM101Grade = input("What was your Grade in OM101: ")
if int(OM101Grade)==True: #Checks if it is a positive Integer
    sumOfGrades = sumOfGrades + int(OM101Grade)
    numOfClasses = numOfClasses + 1
    
FI101Grade = input("What was your Grade in FI101: ")
if int(FI101Grade)==True: #Checks if it is a positive Integer
    sumOfGrades = sumOfGrades + int(FI101Grade)
    numOfClasses = numOfClasses + 1
    
MG101Grade = input("What was your Grade in MG101: ")
if int(MG101Grade)==True: #Checks if it is a positive Integer
    sumOfGrades = sumOfGrades + int(MG101Grade)
    numOfClasses = numOfClasses + 1
    
MK101Grade = input("What was your Grade in MK101: ")
if int(MK101Grade)==True: #Checks if it is a positive Integer
    sumOfGrades = sumOfGrades + int(MK101Grade)
    numOfClasses = numOfClasses + 1
                
#If the user inputs a grade, add it to the calculation


print ("Num Classes",numOfClasses)
print ("sum", sumOfGrades)
print("Your GPA Is: ", ((sumOfGrades/numOfClasses)*4)/100)
#(How many variables will you need?)
#if the user has no grade in a class, they will enter a blank. Do not include these in GPA Calculation
#at end of all classes, calculate GPA
# Out:
# What was your Grade in AC11: 190
# AC11 190
# What was your Grade in AC12: 90
# What was your Grade in IS100: 90
# What was your Grade in OM101: 90
# What was your Grade in FI101: 90
# What was your Grade in MG101: 90
# What was your Grade in MK101: 90
# Num Classes 1
# sum 190
# Your GPA Is:  7.6

# %% [markdown]
# #

# %%
#MISSED LAST CLASS NOTES

#RATING=FACTOR
#if positives are >  undefined, neutral, negative
    #factor = factor*(positive / greatest of undefined, neutral, negative)
#if negatives are > positives, undefined, neutral
    #factor is reduced
    #factor = factor * (positives/negatives)
#otherwise stick to the same factor in the csv
#each trade = newfactor * 10000
#stop at 1000000
import pandas as pd
file=pd.read_csv("sentiment_analysis_pos_neg.csv")
length=file.index.size
Total = 0
index = 0
for i in range (length):
    Positives = (file.at[i,"Positives"])
    Negatives = (file.at[i,"Negatives"])
    Neutrals = (file.at[i,"Neutrals"])
    Undefineds = (file.at[i,"Undefineds"])
    Rating = (file.at[i, "Rating"])
    Price = (file.at[i, "Price"])
    
    
    if (Positives + Negatives) > (Undefineds + Neutrals):
        if Positives > Negatives:
            Factor = Rating * (Positives/Negatives)
            TradeAmount=10000*Factor
            Total=Total+TradeAmount
            Condition = 1
            index = i            
        elif Negatives > Positives:
            Factor = Rating * ((Positives/Negatives)*.95)
            TradeAmount=10000*Factor
            Total=Total+TradeAmount
            Condition = 1
            index = i         
    else:
        if Neutrals > Undefineds and Positives > Negatives:
            Factor = Rating * (Positives/(Negatives + Neutrals))
            TradeAmount=10000*Factor
            Total=Total+TradeAmount
            Condition = 2
            index = i
        elif Neutrals > Undefineds and Positives < Negatives:
            Factor = Rating * ((Positives + Neutrals)/(Negatives + Neutrals))
            TradeAmount=10000*Factor
            Total=Total+TradeAmount
            Condition = 2
            index = i
    
    print("At index: ", i)
    print("Price: ", Price)
    print("Condition ", Condition, ": ", TradeAmount)
    print("Factor: ", Factor) 
    print("Total: ", Total)
    print("=================")
# Out:
# At index:  0
# Price:  7773.8456
# Condition  1 :  60194.96895752679
# Factor:  6.019496895752679
# Total:  60194.96895752679
# ...
# At index:  1
# Price:  3806.4205
# Condition  1 :  21815.558293354232
# Factor:  2.1815558293354234
# Total:  82010.52725088102
# ...
# At index:  2
# Price:  3889.5840000000003
# Condition  1 :  21815.558293354232
# Factor:  2.1815558293354234
# Total:  82010.52725088102
# ...
# At index:  3
# Price:  1075.4723
# Condition  1 :  423966.4425927211
# Factor:  42.39664425927211
# Total:  505976.9698436021
# ...
# At index:  4
# Price:  7781.3044
# Condition  1 :  423966.4425927211
# Factor:  42.39664425927211
# Total:  505976.9698436021
# ...
# At index:  5
# Price:  6301.767
# Condition  2 :  59159.881738372635
# Factor:  5.915988173837263
# Total:  565136.8515819748
# ...
# At index:  6
# Price:  9044.0135
# Condition  1 :  83699.17960552384
# Factor:  8.369917960552383
# Total:  648836.0311874986
# ...
# At index:  7
# Price:  5991.8964
# Condition  1 :  46939.722318621716
# ...

# %%
#Quiz 
word = "banana"
count = 0
for letter in word:
        if letter =="a":
            count = count + 1
print(count)
# Out:
# 3

# %%
n = 2
while n != 1:
    print(n)
    if n%2 == 0:#n is even
        n = n/2
    else: #n is odd
        n - n*3+1
# Out:
# 2

# %%
#import pandas as pd
import pandas as pd
#read file using pd
file=pd.read_csv("sentiment_analysis_pos_neg.csv")
#get length of file
length=file.index.size
Total = 0
index = 0
oriTrade = 1000
#initialize for loop create variables and link then to elements in file
for i in range (length):
    Positives = (file.at[i,"Positives"])
    Negatives = (file.at[i,"Negatives"])
    Neutrals = (file.at[i,"Neutrals"])
    Undefineds = (file.at[i,"Undefineds"])
    Rating = (file.at[i, "Rating"])
    Price = (file.at[i, "Price"])
    #create if statements for condition 1 "if positives are greater than the largest of negatives, undefined, and neutrals
    if Positives > Negatives or Positives > Neutrals or Positives > Undefineds:
        #multiply rating by positives/negatives 
        Factor = Rating * (Positives/Negatives)
        TradeAmount = oriTrade * Factor
        Total=Total+TradeAmount
        Condition = 1       
    # create if statements for condition 2 if statement "if negatives are greater than the largest of positive, undefined and neutral"
    elif Negatives > Positives or Negatives > Neutrals or Negative > Undefineds:
        Factor = Rating * ((Positives+Undefineds)/(Negatives+Undefineds))
        TradeAmount = oriTrade*Factor
        Total=Total+TradeAmount
        Condition = 2   
    # create if statements for condition 3 if statement "if neutrals are greater than positive, negative and undefined"
    elif Neutrals > Positives or Neutrals > Negatives or Neutrals > Undefineds:
        #if   undefined and positives>negatives,multiply rating by positives/(negatives+undefined)
        if Undefineds > Negatives and Positives > Negatives:
            Factor = Rating * ((Positives)/(Negatives+Undefineds))
            TradeAmount = oriTrade*Factor
            Total=Total+TradeAmount
            Condition = 3                          
        #if undefined and negatives>positives, multiply rating by (positives+undef)/(negatives+undef)
        elif Undefineds > Positives and Negatives > Positives:
            Factor = Rating * ((Positives+Undefineds)/(Negatives+Undefineds))
            TradeAmount = oriTrade*Factor
            Total=Total+TradeAmount
            Condition = 3
                               

#print("At index: ", i)    print("Price: ", Price)   
#print("Condition ", Condition, ": ", TradeAmount)  
#print("Buy or sell or ignore")
#print("Factor: ", Factor)     print("Total: ", Total)    #print("=================")
    print("At index: ", i)
    print("Price: ", Price)
    if Price <= Rating*oriTrade:
        print("Buy!")
    elif Price >= Rating*oriTrade:
        print("Short!")
    print("Condition ", Condition, ": Trade amount is: ", TradeAmount)
    print("Factor: ", Factor) 
    print("Total: ", Total)
    print("=================")
# Out:
# At index:  0
# Price:  7773.8456
# Short!
# Condition  1 : Trade amount is:  6336.312521844926
# Factor:  6.336312521844926
# Total:  6336.312521844926
# ...
# At index:  1
# Price:  3806.4205
# Short!
# Condition  1 : Trade amount is:  2296.3745571951827
# Factor:  2.2963745571951826
# Total:  8632.687079040108
# ...
# At index:  2
# Price:  3889.5840000000003
# Short!
# Condition  1 : Trade amount is:  22082.071386350268
# Factor:  22.08207138635027
# Total:  30714.758465390376
# ...
# At index:  3
# Price:  1075.4723
# Buy!
# Condition  1 : Trade amount is:  42396.64425927211
# Factor:  42.39664425927211
# Total:  73111.40272466248
# ...
# At index:  4
# Price:  7781.3044
# Short!
# Condition  1 : Trade amount is:  27328.665689267847
# Factor:  27.328665689267847
# Total:  100440.06841393032
# ...
# At index:  5
# Price:  6301.767
# Short!
# Condition  2 : Trade amount is:  5883.26220281292
# Factor:  5.88326220281292
# Total:  106323.33061674325
# ...
# At index:  6
# Price:  9044.0135
# Buy!
# ...
